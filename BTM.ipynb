# %% [markdown]
# ## Biterm Topic Model

# %% [markdown]
# ### Import data

# %%
import json

with open('preprocessing/data.json', 'r') as f:
    documents = json.load(f)
    texts = [' '.join([word for word in text]) for text in documents]

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(texts, columns=['headline_text'])
df.head()
# Out:
#                                        headline_text
# 0  апрель год коллаборация телескоп горизонт собы...
# 1  быстрый радиовсплеск год пора астрофизик удовл...
# 2  долгий время реакция циклоприсоединение реакци...
# 3  учёный чехия франция помощь метод трёхмерный д...
# 4  клетка друг друг помощь химический сигнал веще...

# %% [markdown]
# ### Create corpus and vocabulary

# %%
from gensim import corpora

# Map each token to a unique ID
dictionary = corpora.Dictionary(documents)
print(f'Number of unique tokens: {len(dictionary)}')

# Filter out tokens by frequency
min_doc, max_doc = 15, .2
dictionary.filter_extremes(no_below=min_doc, no_above=max_doc)
print(f'Number of unique tokens (filtered): {len(dictionary)}')

# Create a BOW corpus
corpus = [dictionary.doc2bow(doc) for doc in documents]
print(f'Number of documents: {len(corpus)}')
# Out:
# Number of unique tokens: 43392
# Number of unique tokens (filtered): 4901
# Number of documents: 2289

# %% [markdown]
# ### Create a sparse matrix and vocabilary from gensim's BOW document representation

# %%
import numpy as np
from gensim import matutils

def bow_iterator(docs, dictionary):
    for doc in docs:
        yield dictionary.doc2bow(doc)

def get_term_matrix(msgs, dictionary):
    bow = bow_iterator(msgs, dictionary)
    X = np.transpose(matutils.corpus2csc(bow).astype(np.int64))
    return X

def get_vocab(dictionary):
    tmp = []
    for i in range(len(dictionary)):
        tmp.append(dictionary.get(i))
    return tuple(tmp)

def get_vocab_dict(dictionary):
    return {k: v for k, v in dictionary.token2id.items()}


# Obtain term frequency in a sparse matrix and corpus vocabulary
# these are used instead of the default ones
X = get_term_matrix(documents, dictionary)
vocab = get_vocab(dictionary)
vocab_dict = get_vocab_dict(dictionary)

# %%
import bitermplus as btm

tf = np.array(X.sum(axis=0)).ravel()

# Vectorize documents
docs_vec = btm.get_vectorized_docs(texts, vocab)
docs_lens = list(map(len, docs_vec))

# Generate biterms
biterms = btm.get_biterms(docs_vec)

# %% [markdown]
# ### Train and run the Biterm topic model

# %%
num_topics = 15
top_words = 15 # number of top words for coherence calculation

# Train the model
biterm_model = btm.BTM(X, vocab, seed=12321, T=num_topics, \
                       M=top_words, alpha=50/8, beta=0.01)

# Run the model
biterm_model.fit(biterms, iterations=50)
# Out:
# 100%|██████████| 50/50 [01:01<00:00,  1.23s/it]

# %%
# Calculate documents vs topics probability matrix
p_zd = biterm_model.transform(docs_vec)
# Out:
# 100%|██████████| 2289/2289 [00:00<00:00, 2958.90it/s]

# %% [markdown]
# ### Show top words for each topic

# %%
num_words = 15
btm.get_top_topic_words(biterm_model, num_words)
# Out:
#          topic0        topic1          topic2     topic3     topic4  \
# 0     галактика        физика           самка   растение      птица
# 1         масса       решение           самец   бактерия  насекомое
# 2        звезда         наука         половой   эукариот      песня
# 3       частица        проект       потомство  насекомое      крыло
# 4       энергия        страна             пол       гриб      самец
# 5   чёрный_дыра      участник         партнёр    паразит   динозавр
# 6          ядро          язык            яйцо       муха     хищник
# 7        физика    специалист     размножение  водоросль      самка
# 8      нейтрино       ребёнок           птица    муравей  семейство
# 9     излучение         книга  репродуктивный     хозяин    окраска
# 10  космический    социальный      социальный     цветок       звук
# 11    вселенная      общество      спаривание       лист     сигнал
# 12     детектор    публикация           успех     дерево       змея
# 13       распад  человеческий         ребёнок    колония       перо
# 14       протон      реальный           выбор    личинка       цвет
#
#          topic5         topic6          topic7             topic8  \
# 0         кость      вымирание           волна            мутация
# 1       остаток          птица        электрон          хромосома
# 2       находка       растение            поле           полезный
# 3     отложение   разнообразие            атом  приспособленность
# 4       морской         климат         энергия             аллель
# 5    ископаемое    численность         частица    видообразование
# 6           зуб            лес       квантовый            частота
# 7        порода        морской       излучение          адаптация
# 8   палеонтолог         остров         частота            вредный
# 9          рыба         хищник  магнитный_поле       изменчивость
# 10         след          район        движение              копия
# 11      образец  млекопитающее       измерение            генотип
# 12     динозавр     сообщество           фотон          поколение
# 13       скелет     территория   электрический       разнообразие
# 14     раковина  экологический             луч             замена
#
#          topic9       topic10        topic11           topic12     topic13  \
# 0           днк    химический         порода      неандерталец        мозг
# 1          мышь       фермент      атмосфера           сапиенс      нейрон
# 2       мутация       энергия         мантия               днк      сигнал
# 3       опухоль        синтез        планета   неандертальский        мышь
# 4         вирус      бактерия           кора            орудие    рецептор
# 5      бактерия       продукт           зона      человеческий     нервный
# 6    экспрессия          атом         земной          культура        кора
# 7         белка      мембрана        глубина             кость    обучение
# 8           рак    соединение          океан            африка  социальный
# 9         ткань           ион         кратер         денисовец      память
# 10    клеточный  органический            газ            пещера      стимул
# 11  заболевание      кислород            лёд          шимпанзе       запах
# 12      фермент       кислота     содержание         денисовца        муха
# 13      раковый       углерод  магматический  митохондриальный        опыт
# 14     иммунный  концентрация        минерал           примесь  испытуемый
#
#            topic14
# 0      позвоночный
# 1          нервный
# 2            ветвь
# 3            червь
# 4          личинка
# 5   многоклеточный
# 6        билатерия
# 7            губка
# 8             рыба
# 9       конечность
# 10      экспрессия
# 11        передний
# 12         эмбрион
# 13           орган
# 14             рот

# %% [markdown]
# ### Calculate metrics

# %%
perplexity = btm.perplexity(biterm_model.matrix_topics_words_, p_zd, X, num_topics)
coherence = btm.coherence(biterm_model.matrix_topics_words_, X, M=top_words)

print(f'Perplexity: {perplexity}\n' +
      f'Average coherence score: {sum(coherence)/num_topics}')
# Out:
# Perplexity: 1216.4758185708436
# Average coherence score: -156.520366779074

# %% [markdown]
# ### Show most probable topic for each document

# %%
btm.get_docs_top_topic(texts, biterm_model.matrix_docs_topics_)
# Out:
#                                               documents  label
# 0     апрель год коллаборация телескоп горизонт собы...      0
# 1     быстрый радиовсплеск год пора астрофизик удовл...      0
# 2     долгий время реакция циклоприсоединение реакци...     10
# 3     учёный чехия франция помощь метод трёхмерный д...      7
# 4     клетка друг друг помощь химический сигнал веще...     13
# ...                                                 ...    ...
# 2284  головоногий моллюск наутилус глаз похожий слож...     14
# 2285  мезомицетозой открытый одноклеточный родственн...     14
# 2286  современный биология исследование ген семейств...     14
# 2287  бесчелюстной древний группа позвоночный животн...     14
# 2288  латимерия единственный современный представите...     14
#
# [2289 rows x 2 columns]

# %% [markdown]
# ### Show top documents for each topic

# %%
docs_num = 5
btm.get_top_topic_docs(texts, biterm_model.matrix_docs_topics_, docs_num)
# Out:
#                                               topic0  \
# 0  чёрный_дыра интересный объект космолог астрофи...
# 1  главный коллаборация большой адронный коллайде...
# 2  галактика внешний среда газ ядро сверхмассивны...
# 3  группа учёный специальный_астрофизический_обсе...
# 4  международный группа астрофизик далёкий массив...
#
#                                               topic1  \
# 0  жизнь дмитрий борисович зимин горестный отчаян...
# 1  жизнь дмитрий борисович зимин горестный отчаян...
# 2  октябрь лауреат нобелевский_премия экономика г...
# 3  социолог результат пилотный исследование малои...
# 4  историк возможный связь усложнение общественны...
#
#                                               topic2  \
# 0  конфликт эволюционный интерес самец самка секс...
# 1  животное оптимальный репродуктивный стратегия ...
# 2  самец насекомое паук время ухаживание самка св...
# 3  десятилетний наблюдение популяция вилорог резе...
# 4  рыба-игла морской коньковый забота потомство м...
#
#                                               topic3  \
# 0  фенотипический признак насекомое ген насекомое...
# 1  эволюционный связь насекомое-опылитель цветков...
# 2  американский муравей-листорез муравейник грибн...
# 3  швейцарский учёный дивергентный эволюция репа ...
# 4  сложный симбиотический отношение живой организ...
#
#                                               topic4  \
# 0  палеонтолог бирманский меловой янтарь возраст ...
# 1  пернатый ископаемый мезозойский эра очередной ...
# 2  американский учёный глубокий чёрный окраска пе...
# 3  янтарь возраст год птенец примитивный энанциор...
# 4  птица известный разнообразный голос пора палео...
#
#                                               topic5  \
# 0  группа американский учёный раннемеловой шляпоч...
# 1  вендобионт загадочный гигантский ископаемое ор...
# 2  палеонтолог южный_америка новый крупный диноза...
# 3  год начало кембрийский период земля бурный раз...
# 4  известняк окрестность немецкий город зольнхофн...
#
#                                               topic6  \
# 0  группа американский учёный последний происхожд...
# 1  сильный сокращение поверхность арктический лёд...
# 2  спор причина массовый вымирание крупный животн...
# 3  район акватория южный_океан оконечность антарк...
# 4  дистанционный метод обследование поверхность з...
#
#                                               topic7  \
# 0  новый явление среда перепрыгивание фонон твёрд...
# 1  японский учёный возможность использование свер...
# 2  сверхпроводимость квантовый состояние вещество...
# 3  кажущийся простота трение дискуссионный пробле...
# 4  группа учёный констанцский_университет германи...
#
#                                               topic8  \
# 0  инверсия хромосомный перестройка участок хромо...
# 1  цихлида африка небольшой вулканический озёры к...
# 2  сравнительный анализ полный геном африканский ...
# 3  важный этап видообразование формирование генет...
# 4  организм хромосомный перестройка генетический ...
#
#                                               topic9  \
# 0  перспективный подход лечение рак применение т-...
# 1  терапия помощь лимфоцит собственный иммунный к...
# 2  американский учёный роль корень рак раковый ст...
# 3  немецкий учёный новый противораковый вакцина м...
# 4  месяц год успешный удаление раковый опухоль ра...
#
#                                              topic10  \
# 0  металло-карбеноид необычный нестабильный молек...
# 1  немецкий химик жидкометаллический катализатор ...
# 2  хлорoсилан важный реагент химический промышлен...
# 3  группа канадский учёный новый механизм нейтрал...
# 4  натрий-калиевый насос натрий-калиевый помпа бе...
#
#                                              topic11  \
# 0  результат датирование образец лава плато керге...
# 1  результат петролый-термомеханический моделиров...
# 2  начало мезозой суперконтинент пангей часть зон...
# 3  моделирование суперкомпьютер интерпретация сей...
# 4  океанический кора планета поверхностный слой п...
#
#                                              topic12  \
# 0  коллектив ведущий генетик палеоантрополог вели...
# 1  достижение палеогеномик предок современный чел...
# 2  команда сванте пеэбый работа геном древний чел...
# 3  международный команда палеогенетик глава свант...
# 4  археологический остров юго-восточный_азия прих...
#
#                                              topic13  \
# 0  чувство радость удовольствие активность дофами...
# 1  человек животное безобидный вещь прошлый болез...
# 2  крыса друг друг безопасный еда навык связанный...
# 3  трансгенный мышь аналог человеческий болезнь а...
# 4  нейробиолог время бодрствование новый опыт неу...
#
#                                              topic14
# 0  жаберный щель уникальный признак тип хордовое ...
# 1  проблема происхождение уникальный трубчатый це...
# 2  hox-ген важный роль передне-задний разметка те...
# 3  международный команда учёный изучение интересн...
# 4  время эмбриональный развитие зародыш зародышев...

# %% [markdown]
# ### Visualize the results

# %%
import tmplot as tmp

phi = tmp.get_phi(biterm_model)
terms_probs = tmp.calc_terms_probs_ratio(phi, topic=5, lambda_=1)

tmp.plot_terms(terms_probs)
# Out:
# C:\Users\satan\AppData\Roaming\Python\Python39\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)
