# %% [markdown]
# ## Biterm Topic Model

# %% [markdown]
# ### Import data

# %%
import os
import json

dirpath = os.getcwd() + '\\preprocessing\\tokens.json'

with open(dirpath, 'r') as f:
    documents = json.load(f)
    texts = [' '.join(doc) for doc in documents]

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(texts, columns=['headline_text'])
df.head()
# Out:
#                                        headline_text
# 0  март год полный солнечный_затмение полный фаза...
# 1  сентябрь полный лунный_затмение европейский ча...
# 2  март год полный солнечный_затмение полный фаза...
# 3  июль год продолжительный нынешний столетие пол...
# 4  первый упоминание солнечный_затмение год эра д...

# %% [markdown]
# ### Create corpus and vocabulary

# %%
from gensim import corpora

# Map each token to a unique ID
dictionary = corpora.Dictionary(documents)
print(f'Number of unique tokens: {len(dictionary)}')

# Filter out tokens by frequency
min_doc, max_doc = 15, .2
dictionary.filter_extremes(no_below=min_doc, no_above=max_doc)
print(f'Number of unique tokens (filtered): {len(dictionary)}')

# Create a BOW corpus
corpus = [dictionary.doc2bow(doc) for doc in documents]
print(f'Number of documents: {len(corpus)}')
# Out:
# Number of unique tokens: 30281
# Number of unique tokens (filtered): 3231
# Number of documents: 1260

# %% [markdown]
# ### Create a sparse matrix and vocabilary from gensim's BOW document representation

# %%
import numpy as np
from gensim import matutils

def bow_iterator(docs, dictionary):
    for doc in docs:
        yield dictionary.doc2bow(doc)

def get_term_matrix(msgs, dictionary):
    bow = bow_iterator(msgs, dictionary)
    X = np.transpose(matutils.corpus2csc(bow).astype(np.int64))
    return X

def get_vocab(dictionary):
    tmp = []
    for i in range(len(dictionary)):
        tmp.append(dictionary.get(i))
    return tuple(tmp)

def get_vocab_dict(dictionary):
    return {k: v for k, v in dictionary.token2id.items()}


# Obtain term frequency in a sparse matrix and corpus vocabulary
# these are used instead of the default ones
X = get_term_matrix(documents, dictionary)
vocab = get_vocab(dictionary)
vocab_dict = get_vocab_dict(dictionary)

# %%
import bitermplus as btm

tf = np.array(X.sum(axis=0)).ravel()

# Vectorize documents
docs_vec = btm.get_vectorized_docs(texts, vocab)
docs_lens = list(map(len, docs_vec))

# Generate biterms
biterms = btm.get_biterms(docs_vec)

# %% [markdown]
# ### Train and run the Biterm topic model

# %%
num_topics = 15
top_words = 15 # number of top words for coherence calculation

# Train the model
biterm_model = btm.BTM(X, vocab, seed=12321, T=num_topics, \
                       M=top_words, alpha=50/8, beta=0.01)

# Run the model
biterm_model.fit(biterms, iterations=50)
# Out:
# 100%|██████████| 50/50 [00:28<00:00,  1.73it/s]

# %%
# Calculate documents vs topics probability matrix
p_zd = biterm_model.transform(docs_vec)
# Out:
# 100%|██████████| 1260/1260 [00:00<00:00, 3694.64it/s]

# %% [markdown]
# ### Calculate metrics

# %%
perplexity = btm.perplexity(biterm_model.matrix_topics_words_, p_zd, X, num_topics)
coherence = btm.coherence(biterm_model.matrix_topics_words_, X, M=top_words)

print(f'Perplexity: {perplexity}' +
      f'\nCoherence score: {coherence}')
# Out:
# Perplexity: 964.6686193783468
# Coherence score: [-150.82009045 -164.18126106 -146.45792799 -122.63203931 -180.36055583
#  -100.99972679 -142.93398439 -114.88363067 -134.17174807 -136.1583634
#  -150.50400074 -136.94536709 -189.10491261 -181.43845381 -170.12304129]

# %% [markdown]
# ### Show most probable topic for each document

# %%
btm.get_docs_top_topic(texts, biterm_model.matrix_docs_topics_)
# Out:
#                                               documents  label
# 0     март год полный солнечный_затмение полный фаза...      3
# 1     сентябрь полный лунный_затмение европейский ча...      3
# 2     март год полный солнечный_затмение полный фаза...      3
# 3     июль год продолжительный нынешний столетие пол...      3
# 4     первый упоминание солнечный_затмение год эра д...      3
# ...                                                 ...    ...
# 1255  группа физик гарвардский техасский_университет...      1
# 1256  иранский физика эксперимент вращение плёнка жи...      1
# 1257  физик новый тип сверхпроводник общий химически...      1
# 1258  исследователь бордо франция вихрь определённый...      1
# 1259  группа физик сша россия германия бельгия полны...      1
#
# [1260 rows x 2 columns]

# %% [markdown]
# ### Show top words for each topic

# %%
num_words = 15
btm.get_top_topic_words(biterm_model, num_words)
# Out:
#                      topic0             topic1              topic2  \
# 0               позвоночный               атом               геном
# 1              эволюционный           электрон                 днк
# 2                    предок               поле            бактерия
# 3                     ветвь     магнитный_поле            эукариот
# 4              общий_предок     сверхпроводник             фермент
# 5                     губка  сверхпроводимость             мутация
# 6                   личинка          квантовый  последовательность
# 7   многоклеточный_животное            частота            растение
# 8           нервный_система    сверхпроводящий              синтез
# 9                 гребневик          излучение         митохондрия
# 10                   стадия             графен               белка
# 11            членистоногий        электронный        аминокислота
# 12                 эукариот          магнитный               вирус
# 13                  hox-ген             плёнка        молекулярный
# 14                билатерия         устройство           хромосома
#
#          topic3      topic4        topic5         topic6        topic7  \
# 0          луна       самец        звезда          птица        физика
# 1      затмение       самка     галактика      популяция      нейтрино
# 2        солнце       особь   чёрный_дыра         хищник      детектор
# 3          фаза   насекомое     излучение        окраска          ядро
# 4      телескоп     половой          ядро   генетический        протон
# 5       планета      сигнал     солнечный          отбор     измерение
# 6        орбита   потомство     вселенная       растение        распад
# 7      астероид        яйцо        солнце    численность      электрон
# 8       аппарат     колония      звёздный         дерево  коллаборация
# 9        высота        муха   космический          особь       событие
# 10       звезда       птица          дыра   разнообразие     коллайдер
# 11       комета   популяция      астроном          геном       материя
# 12      спутник     муравей        спектр   эволюционный         фотон
# 13    солнечный  спаривание  белый_карлик      семейство       нейтрон
# 14  космический       выбор  пространство  экологический  столкновение
#
#           topic8        topic9        topic10           topic11  \
# 0         порода         геном         физика           опухоль
# 1      атмосфера         кость        научный              мышь
# 2           зона       сапиенс          наука               рак
# 3        углерод       находка         проект           мутация
# 4        глубина  неандерталец        решение             ткань
# 5       кислород        пещера       эйнштейн        экспрессия
# 6         мантия          след      профессор          рецептор
# 7     содержание           днк          книга          метастаз
# 8         железо     популяция     публикация        нормальный
# 9          океан  генетический     физический           раковый
# 10       минерал        предок            век            нейрон
# 11       планета        остров     астрофизик             кровь
# 12  концентрация           зуб         премия           пациент
# 13     глубинный  человеческий  теоретический       заболевание
# 14          ядро       образец     специалист  стволовой_клетка
#
#           topic12      topic13       topic14
# 0           волна     растение          мозг
# 1           капля    вымирание        нейрон
# 2           точка        океан         отбор
# 3     изображение      морской      культура
# 4       колебание    атмосфера        сигнал
# 5         частота       климат       ребёнок
# 6             лёд   содержание          мышь
# 7          сигнал   сообщество    социальный
# 8       измерение        район        память
# 9   распределение  численность     популяция
# 10         воздух          лес  генетический
# 11  моделирование         рыба         запах
# 12            шум         лист         особь
# 13        средний     кислород       реакция
# 14         расчёт   территория  человеческий

# %% [markdown]
# ### Show top documents for each topic

# %%
docs_num = 5
btm.get_top_topic_docs(texts, biterm_model.matrix_docs_topics_, docs_num)
# Out:
#                                               topic0  \
# 0  жаберный_щель уникальный признак тип хордовое ...
# 1  проблема происхождение уникальный трубчатый це...
# 2  коралловый_полип древний эволюционный_ветвь гр...
# 3  древний эволюционный_ствол двусторонне-симметр...
# 4  германский палеонтолог древний головохоботный_...
#
#                                               topic1  \
# 0  сверхпроводимость квантовый состояние вещество...
# 1  японский учёный возможность использование свер...
# 2  группа физик сша россия германия бельгия полны...
# 3  последний теоретический экспериментальный иссл...
# 4  маленький мочь сверхпроводник сверхпроводящий ...
#
#                                               topic2  \
# 0  учёный чехия канада одноклеточный эукариотичес...
# 1  нуклеиновый_кислота носитель генетический инфо...
# 2  вопрос происхождение синтез белок аппарат тран...
# 3  коллектив американский генетик свойство работа...
# 4  эукариот результат симбиогенез архейный клетка...
#
#                                               topic3  \
# 0  лунный_затмение февраль год полный житель евро...
# 1  мартовский затмение год восточный район европе...
# 2  сентябрь полный лунный_затмение европейский ча...
# 3  первый весенний месяц год житель земля великол...
# 4  июль год продолжительный нынешний столетие пол...
#
#                                               topic4  \
# 0  комар мочь частота акустический брачный сигнал...
# 1  устойчивый сохранение популяция разный группа ...
# 2  конфликт эволюционный интерес самец самка секс...
# 3  самка африканский бабочка-нимфалида вид частый...
# 4  паук самка крупный агрессивный самец период сп...
#
#                                               topic5  \
# 0  группа астроном новый ультрафиолетовый телеско...
# 1  спектр квазар гамма-всплеск яркий объект вселе...
# 2  интернациональный коллектив астроном астрофизи...
# 3  время вселенная ускорение галактика млечный_пу...
# 4  помощь космический телескоп год вселенная ульт...
#
#                                               topic6  \
# 0  пример разный популяция вид бразильский пальма...
# 1  канадский американский зоолог певчий_птица тро...
# 2  бейтсовский мимикрия неядовитый вид ядовитый я...
# 3  контрастный окраска наземный хищный млекопитаю...
# 4  африканский птица нектарница нектар цветковый ...
#
#                                               topic7  \
# 0  главный коллаборация большой_адронный коллайде...
# 1  коллаборация любопытный результат новый анализ...
# 2  коллаборация обработка настоящий время статист...
# 3  прошедший март серия конференция результат бол...
# 4  рутинный поиск эффект новый_физика канал рожде...
#
#                                               topic8  \
# 0  результат петролый-термомеханический моделиров...
# 1  газово-жидкий включение кристалл породообразую...
# 2  австралийский учёный основа результат изотопны...
# 3  гранат алмаз кимберлитовый_трубка яхерсфонтейн...
# 4  катархейский гадейский эон год ранний период г...
#
#                                               topic9  \
# 0  обобщение материал собранный пещера мандрен фр...
# 1  археологический остров юго-восточный_азия прих...
# 2  денисов_пещера алтай бесценный археологический...
# 3  международный_коллектив палеогенетик археолог ...
# 4  денисовский человек пора известный скудный нах...
#
#                                              topic10  \
# 0  жизнь дмитрий_борисович_зимин горестный отчаян...
# 1  жизнь дмитрий_борисович_зимин горестный отчаян...
# 2  начало неделя сми сенсационный сообщение омски...
# 3  декабрь окружный федеральный судья город гарри...
# 4  великий физика сила время детальный изучение о...
#
#                                              topic11  \
# 0  группа исследователь клетка раковый_опухоль де...
# 1  американский учёный роль корень рак раковый ст...
# 2  линия лабораторный мышь формирование новый лим...
# 3  модель рак_молочный железа мышь американский а...
# 4  немецкий учёный новый противораковый вакцина м...
#
#                                              topic12  \
# 0  определённый условие капля жидкость горячий по...
# 1  материал подверженный обледенение авиастроение...
# 2  орёл решка определённый условие результат брос...
# 3  рост гигантский дюна счёт поглощение мелкий дю...
# 4  игровой вид спорт мяч воздух путь удивление иг...
#
#                                              topic13  \
# 0  спор причина массовый_вымирание крупный животн...
# 1  район акватория южный_океан оконечность антарк...
# 2  эколог шведский университет_умео биогенный эле...
# 3  фитопланктон процесс фотосинтез органический_в...
# 4  дистанционный метод обследование поверхность з...
#
#                                              topic14
# 0  сочувствие человек боль мозг область чувство с...
# 1  американский учёный ряд поведенческий эксперим...
# 2  нейробиолог влияние полиморфизм ген рецептор д...
# 3  работа помощь экономический игра альтруистичес...
# 4  ангедония утрата способность удовольствие глав...

# %% [markdown]
# ### Visualize the results

# %%
import tmplot as tmp

topics_coords = tmp.prepare_coords(biterm_model)

tmp.plot_scatter_topics(topics_coords, size_col='size', label_col='label')
# Out:
# C:\Users\satan\AppData\Roaming\Python\Python39\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\satan\AppData\Roaming\Python\Python39\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# alt.LayerChart(...)

# %%
phi = tmp.get_phi(biterm_model)
terms_probs = tmp.calc_terms_probs_ratio(phi, topic=5, lambda_=1)

tmp.plot_terms(terms_probs)
# Out:
# alt.Chart(...)
